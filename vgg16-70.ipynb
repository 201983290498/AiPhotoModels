# %%
#基本包导入
import numpy as np
import time
import tensorflow as tf
import matplotlib.pyplot as plt

#实时数据增强功能 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#调用显卡内存分配指令需要的包
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
#显卡内存分配指令：按需分配 
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
#数据提取
(x_img_train,y_label_train), (x_img_test, y_label_test)=tf.keras.datasets.cifar100.load_data() 
a = y_label_test.copy();b = y_label_train[0:10000].copy(); 
a1 = x_img_test.copy();b1 = x_img_train[0:10000].copy();
y_label_test = b;y_label_train[0:10000] =a;
x_img_train[0:10000] = a1;x_img_test=b1;

# %%
#z-score标准化
mean = np.mean(x_img_train, axis=(0, 1, 2, 3))#四个维度 批数 像素x像素 通道数
std = np.std(x_img_train, axis=(0, 1, 2, 3))

x_img_train = (x_img_train - mean) / (std + 1e-7)#trick 加小数点 避免出现整数 
x_img_test = (x_img_test - mean) / (std + 1e-7) 

#one-hot独热映射
y_label_train = tf.keras.utils.to_categorical(y_label_train, 100)
y_label_test = tf.keras.utils.to_categorical(y_label_test, 100)

# %%
model = tf.keras.Sequential()

#conv1
model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=[3, 3], input_shape=(32, 32, 3), strides=1,activation='relu',
                                        padding='SAME', kernel_regularizer=tf.keras.regularizers.l2(0.0005)))
model.add(tf.keras.layers.BatchNormalization()) #批标准化
model.add(tf.keras.layers.Dropout(0.3)) #随机丢弃神经元，防止过拟合
#conv2
model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=[3, 3], strides=1,activation='relu',
                                        padding='SAME', kernel_regularizer=tf.keras.regularizers.l2(0.0005)))
model.add(tf.keras.layers.BatchNormalization()) 
#最大池化1
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))


#conv3
model.add(tf.keras.layers.Conv2D(filters=128, kernel_size=[3, 3], strides=1,activation='relu',
                                        padding='SAME', kernel_regularizer=tf.keras.regularizers.l2(0.0005)))
model.add(tf.keras.layers.BatchNormalization()) 
model.add(tf.keras.layers.Dropout(0.4))
#conv4
model.add(tf.keras.layers.Conv2D(filters=128, kernel_size=[3, 3], strides=1,activation='relu',
                                        padding='SAME', kernel_regularizer=tf.keras.regularizers.l2(0.0005)))
model.add(tf.keras.layers.BatchNormalization()) 
#最大池化2
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))



#conv5
model.add(tf.keras.layers.Conv2D(filters=256, kernel_size=[3, 3], strides=1,activation='relu',
                                        padding='SAME', kernel_regularizer=tf.keras.regularizers.l2(0.0005)))
model.add(tf.keras.layers.BatchNormalization()) 
model.add(tf.keras.layers.Dropout(0.4))
#conv6
model.add(tf.keras.layers.Conv2D(filters=256, kernel_size=[3, 3], strides=1,activation='relu',
                                        padding='SAME', kernel_regularizer=tf.keras.regularizers.l2(0.0005)))
model.add(tf.keras.layers.BatchNormalization()) 
model.add(tf.keras.layers.Dropout(0.4))
#conv7
model.add(tf.keras.layers.Conv2D(filters=256, kernel_size=[3, 3], strides=1,activation='relu',
                                        padding='SAME', kernel_regularizer=tf.keras.regularizers.l2(0.0005)))
model.add(tf.keras.layers.BatchNormalization()) 
#最大池化3
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))


#conv8
model.add(tf.keras.layers.Conv2D(filters=512, kernel_size=[3, 3], strides=1,activation='relu',
                                        padding='SAME', kernel_regularizer=tf.keras.regularizers.l2(0.0005)))
model.add(tf.keras.layers.BatchNormalization()) 
model.add(tf.keras.layers.Dropout(0.4))
#conv9
model.add(tf.keras.layers.Conv2D(filters=512, kernel_size=[3, 3], strides=1,activation='relu',
                                        padding='SAME', kernel_regularizer=tf.keras.regularizers.l2(0.0005)))
model.add(tf.keras.layers.BatchNormalization()) 
model.add(tf.keras.layers.Dropout(0.4))
#conv10
model.add(tf.keras.layers.Conv2D(filters=512, kernel_size=[3, 3], strides=1,activation='relu',
                                        padding='SAME', kernel_regularizer=tf.keras.regularizers.l2(0.0005)))
model.add(tf.keras.layers.BatchNormalization()) 
#最大池化4
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))


#conv11
model.add(tf.keras.layers.Conv2D(filters=512, kernel_size=[3, 3], strides=1,activation='relu',
                                        padding='SAME', kernel_regularizer=tf.keras.regularizers.l2(0.0005)))
model.add(tf.keras.layers.BatchNormalization()) 
model.add(tf.keras.layers.Dropout(0.4))
#conv12
model.add(tf.keras.layers.Conv2D(filters=512, kernel_size=[3, 3], strides=1,activation='relu',
                                        padding='SAME', kernel_regularizer=tf.keras.regularizers.l2(0.0005)))
model.add(tf.keras.layers.BatchNormalization()) 
model.add(tf.keras.layers.Dropout(0.4))
#conv13
model.add(tf.keras.layers.Conv2D(filters=512, kernel_size=[3, 3], strides=1,activation='relu',
                                        padding='SAME', kernel_regularizer=tf.keras.regularizers.l2(0.0005)))
model.add(tf.keras.layers.BatchNormalization()) 
#最大池化5
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

#全连接 MLP三层 
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dropout(rate=0.5))


model.add(tf.keras.layers.Dense(units=512,activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0005)))
model.add(tf.keras.layers.BatchNormalization())


model.add(tf.keras.layers.Dense(units=100))
model.add(tf.keras.layers.Activation('softmax'))
#查看摘要
# model.summary()

# %%
#超参数
training_epochs = 500
batch_size = 128
learning_rate = 0.1
momentum = 0.9 #SGD加速动量
lr_decay = 1e-6 #学习衰减
lr_drop = 20 #衰减倍数

tf.random.set_seed(777)#可复现

# %%
def lr_scheduler(epoch):
    return learning_rate * (0.5 ** (epoch // lr_drop))

reduce_lr = tf.keras.callbacks.LearningRateScheduler(lr_scheduler)

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,  # 布尔值。将输入数据的均值设置为 0，逐特征进行。
    samplewise_center=False,  # 布尔值。将每个样本的均值设置为 0。
    featurewise_std_normalization=False,  # 布尔值。将输入除以数据标准差，逐特征进行。
    samplewise_std_normalization=False,  # 布尔值。将每个输入除以其标准差。
    zca_whitening=False,  # 布尔值。是否应用 ZCA 白化。
    #zca_epsilon  ZCA 白化的 epsilon 值，默认为 1e-6。
    rotation_range=15,  # 整数。随机旋转的度数范围 (degrees, 0 to 180)
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=True,  # 布尔值。随机水平翻转。
    vertical_flip=False)  # 布尔值。随机垂直翻转。

# %%
datagen.fit(x_img_train)

# %%
#配置优化器
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate,
                                    decay=1e-6, momentum=momentum, nesterov=True)
#交换熵、自定义优化器，评价标准。
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
import keras
import os
filepath1 = 'my_train_model1.hdf5'
filepath = "my_VGG16.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(filepath, monitor='val_accuracy', verbose=2,
                         save_best_only=True)
callbacks_test = keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=10)
checkpoint1 = keras.callbacks.ModelCheckpoint(filepath1, monitor='accuracy', verbose=2,
                         save_best_only=True)

checkpoint.best = 0.80

# %%
if(os.path.isfile('my_VGG16.hdf5')):
    model.load_weights('my_VGG16.hdf5')
    print(True)
t1=time.time()
# model.load_weights('cifar100_hdf5/variables.data-00000-of-00002')
model.fit(datagen.flow(x_img_train, y_label_train,
                                 batch_size=batch_size), epochs=training_epochs, verbose=2,
                    steps_per_epoch=x_img_train.shape[0] // batch_size, validation_data=(x_img_test, y_label_test),callbacks=[checkpoint,checkpoint1,reduce_lr],initial_epoch=150)   
t2=time.time()
model.save_weights('cifar1002_hdf5')
CNNfit = float(t2-t1)
print("Time taken: {} seconds".format(CNNfit))
# Out:
# True
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 390 steps, validate on 10000 samples
# Epoch 151/500
#
# Epoch 00151: val_accuracy did not improve from 0.97880
#
# Epoch 00151: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 1.1397 - accuracy: 0.8571 - val_loss: 0.6760 - val_accuracy: 0.9678
# Epoch 152/500
#
# Epoch 00152: val_accuracy did not improve from 0.97880
#
# Epoch 00152: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 1.1000 - accuracy: 0.8587 - val_loss: 0.7021 - val_accuracy: 0.9623
# Epoch 153/500
#
# Epoch 00153: val_accuracy did not improve from 0.97880
#
# Epoch 00153: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 1.0746 - accuracy: 0.8602 - val_loss: 0.6886 - val_accuracy: 0.9653
# Epoch 154/500
#
# Epoch 00154: val_accuracy did not improve from 0.97880
#
# Epoch 00154: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 1.0568 - accuracy: 0.8643 - val_loss: 0.6969 - val_accuracy: 0.9608
# Epoch 155/500
#
# Epoch 00155: val_accuracy did not improve from 0.97880
#
# Epoch 00155: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 1.0283 - accuracy: 0.8686 - val_loss: 0.7308 - val_accuracy: 0.9513
# Epoch 156/500
#
# Epoch 00156: val_accuracy did not improve from 0.97880
#
# Epoch 00156: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 1.0311 - accuracy: 0.8656 - val_loss: 0.7080 - val_accuracy: 0.9565
# Epoch 157/500
#
# Epoch 00157: val_accuracy did not improve from 0.97880
#
# Epoch 00157: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 1.0033 - accuracy: 0.8721 - val_loss: 0.7113 - val_accuracy: 0.9529
# Epoch 158/500
#
# Epoch 00158: val_accuracy did not improve from 0.97880
#
# Epoch 00158: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.9936 - accuracy: 0.8729 - val_loss: 0.7218 - val_accuracy: 0.9488
# Epoch 159/500
#
# Epoch 00159: val_accuracy did not improve from 0.97880
#
# Epoch 00159: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.9763 - accuracy: 0.8780 - val_loss: 0.7223 - val_accuracy: 0.9517
# Epoch 160/500
#
# Epoch 00160: val_accuracy did not improve from 0.97880
#
# Epoch 00160: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.9750 - accuracy: 0.8756 - val_loss: 0.7360 - val_accuracy: 0.9451
# Epoch 161/500
#
# Epoch 00161: val_accuracy did not improve from 0.97880
#
# Epoch 00161: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.9393 - accuracy: 0.8842 - val_loss: 0.7088 - val_accuracy: 0.9534
# Epoch 162/500
#
# Epoch 00162: val_accuracy did not improve from 0.97880
#
# Epoch 00162: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.9219 - accuracy: 0.8902 - val_loss: 0.7132 - val_accuracy: 0.9520
# Epoch 163/500
#
# Epoch 00163: val_accuracy did not improve from 0.97880
#
# Epoch 00163: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.9126 - accuracy: 0.8916 - val_loss: 0.7156 - val_accuracy: 0.9510
# Epoch 164/500
#
# Epoch 00164: val_accuracy did not improve from 0.97880
#
# Epoch 00164: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.9025 - accuracy: 0.8961 - val_loss: 0.7024 - val_accuracy: 0.9531
# Epoch 165/500
#
# Epoch 00165: val_accuracy did not improve from 0.97880
#
# Epoch 00165: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8986 - accuracy: 0.8967 - val_loss: 0.7184 - val_accuracy: 0.9500
# Epoch 166/500
#
# Epoch 00166: val_accuracy did not improve from 0.97880
#
# Epoch 00166: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8887 - accuracy: 0.8967 - val_loss: 0.7114 - val_accuracy: 0.9516
# Epoch 167/500
#
# Epoch 00167: val_accuracy did not improve from 0.97880
#
# Epoch 00167: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8856 - accuracy: 0.8980 - val_loss: 0.6896 - val_accuracy: 0.9558
# Epoch 168/500
#
# Epoch 00168: val_accuracy did not improve from 0.97880
#
# Epoch 00168: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8758 - accuracy: 0.8979 - val_loss: 0.7310 - val_accuracy: 0.9443
# Epoch 169/500
#
# Epoch 00169: val_accuracy did not improve from 0.97880
#
# Epoch 00169: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8725 - accuracy: 0.9013 - val_loss: 0.7242 - val_accuracy: 0.9469
# Epoch 170/500
#
# Epoch 00170: val_accuracy did not improve from 0.97880
#
# Epoch 00170: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8596 - accuracy: 0.9025 - val_loss: 0.7233 - val_accuracy: 0.9454
# Epoch 171/500
#
# Epoch 00171: val_accuracy did not improve from 0.97880
#
# Epoch 00171: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8630 - accuracy: 0.9021 - val_loss: 0.7050 - val_accuracy: 0.9507
# Epoch 172/500
#
# Epoch 00172: val_accuracy did not improve from 0.97880
#
# Epoch 00172: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8577 - accuracy: 0.9016 - val_loss: 0.7306 - val_accuracy: 0.9445
# Epoch 173/500
#
# Epoch 00173: val_accuracy did not improve from 0.97880
#
# Epoch 00173: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8500 - accuracy: 0.9062 - val_loss: 0.7225 - val_accuracy: 0.9461
# Epoch 174/500
#
# Epoch 00174: val_accuracy did not improve from 0.97880
#
# Epoch 00174: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8429 - accuracy: 0.9058 - val_loss: 0.7348 - val_accuracy: 0.9394
# Epoch 175/500
#
# Epoch 00175: val_accuracy did not improve from 0.97880
#
# Epoch 00175: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8438 - accuracy: 0.9055 - val_loss: 0.7161 - val_accuracy: 0.9453
# Epoch 176/500
#
# Epoch 00176: val_accuracy did not improve from 0.97880
#
# Epoch 00176: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8372 - accuracy: 0.9078 - val_loss: 0.7222 - val_accuracy: 0.9425
# Epoch 177/500
#
# Epoch 00177: val_accuracy did not improve from 0.97880
#
# Epoch 00177: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8280 - accuracy: 0.9094 - val_loss: 0.7185 - val_accuracy: 0.9425
# Epoch 178/500
#
# Epoch 00178: val_accuracy did not improve from 0.97880
#
# Epoch 00178: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8215 - accuracy: 0.9119 - val_loss: 0.7204 - val_accuracy: 0.9435
# Epoch 179/500
#
# Epoch 00179: val_accuracy did not improve from 0.97880
#
# Epoch 00179: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8232 - accuracy: 0.9100 - val_loss: 0.7259 - val_accuracy: 0.9424
# Epoch 180/500
#
# Epoch 00180: val_accuracy did not improve from 0.97880
#
# Epoch 00180: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8181 - accuracy: 0.9114 - val_loss: 0.7296 - val_accuracy: 0.9399
# Epoch 181/500
#
# Epoch 00181: val_accuracy did not improve from 0.97880
#
# Epoch 00181: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8133 - accuracy: 0.9143 - val_loss: 0.7168 - val_accuracy: 0.9441
# Epoch 182/500
#
# Epoch 00182: val_accuracy did not improve from 0.97880
#
# Epoch 00182: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8041 - accuracy: 0.9161 - val_loss: 0.7189 - val_accuracy: 0.9432
# Epoch 183/500
#
# Epoch 00183: val_accuracy did not improve from 0.97880
#
# Epoch 00183: accuracy did not improve from 0.91621
# 390/390 - 21s - loss: 0.8017 - accuracy: 0.9155 - val_loss: 0.7077 - val_accuracy: 0.9482
# Epoch 184/500
#
# Epoch 00184: val_accuracy did not improve from 0.97880
#
# Epoch 00184: accuracy improved from 0.91621 to 0.91911, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7892 - accuracy: 0.9191 - val_loss: 0.7201 - val_accuracy: 0.9432
# Epoch 185/500
#
# Epoch 00185: val_accuracy did not improve from 0.97880
#
# Epoch 00185: accuracy did not improve from 0.91911
# 390/390 - 21s - loss: 0.7914 - accuracy: 0.9180 - val_loss: 0.7109 - val_accuracy: 0.9447
# Epoch 186/500
#
# Epoch 00186: val_accuracy did not improve from 0.97880
#
# Epoch 00186: accuracy improved from 0.91911 to 0.92010, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7873 - accuracy: 0.9201 - val_loss: 0.7059 - val_accuracy: 0.9464
# Epoch 187/500
#
# Epoch 00187: val_accuracy did not improve from 0.97880
#
# Epoch 00187: accuracy did not improve from 0.92010
# 390/390 - 21s - loss: 0.7874 - accuracy: 0.9199 - val_loss: 0.7183 - val_accuracy: 0.9429
# Epoch 188/500
#
# Epoch 00188: val_accuracy did not improve from 0.97880
#
# Epoch 00188: accuracy improved from 0.92010 to 0.92070, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7837 - accuracy: 0.9207 - val_loss: 0.7165 - val_accuracy: 0.9416
# Epoch 189/500
#
# Epoch 00189: val_accuracy did not improve from 0.97880
#
# Epoch 00189: accuracy improved from 0.92070 to 0.92210, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7764 - accuracy: 0.9221 - val_loss: 0.7192 - val_accuracy: 0.9413
# Epoch 190/500
#
# Epoch 00190: val_accuracy did not improve from 0.97880
#
# Epoch 00190: accuracy improved from 0.92210 to 0.92336, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7774 - accuracy: 0.9234 - val_loss: 0.7050 - val_accuracy: 0.9460
# Epoch 191/500
#
# Epoch 00191: val_accuracy did not improve from 0.97880
#
# Epoch 00191: accuracy improved from 0.92336 to 0.92342, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7754 - accuracy: 0.9234 - val_loss: 0.7178 - val_accuracy: 0.9420
# Epoch 192/500
#
# Epoch 00192: val_accuracy did not improve from 0.97880
#
# Epoch 00192: accuracy did not improve from 0.92342
# 390/390 - 21s - loss: 0.7709 - accuracy: 0.9222 - val_loss: 0.7051 - val_accuracy: 0.9460
# Epoch 193/500
#
# Epoch 00193: val_accuracy did not improve from 0.97880
#
# Epoch 00193: accuracy did not improve from 0.92342
# 390/390 - 21s - loss: 0.7687 - accuracy: 0.9234 - val_loss: 0.7036 - val_accuracy: 0.9445
# Epoch 194/500
#
# Epoch 00194: val_accuracy did not improve from 0.97880
#
# Epoch 00194: accuracy did not improve from 0.92342
# 390/390 - 21s - loss: 0.7695 - accuracy: 0.9231 - val_loss: 0.7255 - val_accuracy: 0.9381
# Epoch 195/500
#
# Epoch 00195: val_accuracy did not improve from 0.97880
#
# Epoch 00195: accuracy improved from 0.92342 to 0.92555, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7680 - accuracy: 0.9255 - val_loss: 0.7125 - val_accuracy: 0.9402
# Epoch 196/500
#
# Epoch 00196: val_accuracy did not improve from 0.97880
#
# Epoch 00196: accuracy did not improve from 0.92555
# 390/390 - 21s - loss: 0.7604 - accuracy: 0.9255 - val_loss: 0.7234 - val_accuracy: 0.9386
# Epoch 197/500
#
# Epoch 00197: val_accuracy did not improve from 0.97880
#
# Epoch 00197: accuracy did not improve from 0.92555
# 390/390 - 21s - loss: 0.7602 - accuracy: 0.9254 - val_loss: 0.7199 - val_accuracy: 0.9399
# Epoch 198/500
#
# Epoch 00198: val_accuracy did not improve from 0.97880
#
# Epoch 00198: accuracy did not improve from 0.92555
# 390/390 - 21s - loss: 0.7613 - accuracy: 0.9246 - val_loss: 0.7075 - val_accuracy: 0.9435
# Epoch 199/500
#
# Epoch 00199: val_accuracy did not improve from 0.97880
#
# Epoch 00199: accuracy improved from 0.92555 to 0.92691, saving model to my_train_model1.hdf5
# 390/390 - 22s - loss: 0.7561 - accuracy: 0.9269 - val_loss: 0.7060 - val_accuracy: 0.9424
# Epoch 200/500
#
# Epoch 00200: val_accuracy did not improve from 0.97880
#
# Epoch 00200: accuracy did not improve from 0.92691
# 390/390 - 21s - loss: 0.7582 - accuracy: 0.9253 - val_loss: 0.7186 - val_accuracy: 0.9394
# Epoch 201/500
#
# Epoch 00201: val_accuracy did not improve from 0.97880
#
# Epoch 00201: accuracy improved from 0.92691 to 0.92747, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7532 - accuracy: 0.9275 - val_loss: 0.7150 - val_accuracy: 0.9407
# Epoch 202/500
#
# Epoch 00202: val_accuracy did not improve from 0.97880
#
# Epoch 00202: accuracy did not improve from 0.92747
# 390/390 - 21s - loss: 0.7543 - accuracy: 0.9269 - val_loss: 0.7107 - val_accuracy: 0.9422
# Epoch 203/500
#
# Epoch 00203: val_accuracy did not improve from 0.97880
#
# Epoch 00203: accuracy improved from 0.92747 to 0.92930, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7461 - accuracy: 0.9293 - val_loss: 0.7119 - val_accuracy: 0.9408
# Epoch 204/500
#
# Epoch 00204: val_accuracy did not improve from 0.97880
#
# Epoch 00204: accuracy improved from 0.92930 to 0.93032, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7445 - accuracy: 0.9303 - val_loss: 0.7057 - val_accuracy: 0.9422
# Epoch 205/500
#
# Epoch 00205: val_accuracy did not improve from 0.97880
#
# Epoch 00205: accuracy improved from 0.93032 to 0.93181, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7402 - accuracy: 0.9318 - val_loss: 0.7078 - val_accuracy: 0.9416
# Epoch 206/500
#
# Epoch 00206: val_accuracy did not improve from 0.97880
#
# Epoch 00206: accuracy did not improve from 0.93181
# 390/390 - 21s - loss: 0.7456 - accuracy: 0.9298 - val_loss: 0.7118 - val_accuracy: 0.9403
# Epoch 207/500
#
# Epoch 00207: val_accuracy did not improve from 0.97880
#
# Epoch 00207: accuracy did not improve from 0.93181
# 390/390 - 21s - loss: 0.7390 - accuracy: 0.9309 - val_loss: 0.7097 - val_accuracy: 0.9416
# Epoch 208/500
#
# Epoch 00208: val_accuracy did not improve from 0.97880
#
# Epoch 00208: accuracy did not improve from 0.93181
# 390/390 - 21s - loss: 0.7388 - accuracy: 0.9303 - val_loss: 0.7041 - val_accuracy: 0.9432
# Epoch 209/500
#
# Epoch 00209: val_accuracy did not improve from 0.97880
#
# Epoch 00209: accuracy did not improve from 0.93181
# 390/390 - 21s - loss: 0.7378 - accuracy: 0.9311 - val_loss: 0.7172 - val_accuracy: 0.9408
# Epoch 210/500
#
# Epoch 00210: val_accuracy did not improve from 0.97880
#
# Epoch 00210: accuracy improved from 0.93181 to 0.93197, saving model to my_train_model1.hdf5
# 390/390 - 22s - loss: 0.7363 - accuracy: 0.9320 - val_loss: 0.7108 - val_accuracy: 0.9419
# Epoch 211/500
#
# Epoch 00211: val_accuracy did not improve from 0.97880
#
# Epoch 00211: accuracy improved from 0.93197 to 0.93209, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7344 - accuracy: 0.9321 - val_loss: 0.7072 - val_accuracy: 0.9428
# Epoch 212/500
#
# Epoch 00212: val_accuracy did not improve from 0.97880
#
# Epoch 00212: accuracy did not improve from 0.93209
# 390/390 - 21s - loss: 0.7337 - accuracy: 0.9318 - val_loss: 0.7083 - val_accuracy: 0.9410
# Epoch 213/500
#
# Epoch 00213: val_accuracy did not improve from 0.97880
#
# Epoch 00213: accuracy did not improve from 0.93209
# 390/390 - 21s - loss: 0.7342 - accuracy: 0.9310 - val_loss: 0.7091 - val_accuracy: 0.9423
# Epoch 214/500
#
# Epoch 00214: val_accuracy did not improve from 0.97880
#
# Epoch 00214: accuracy did not improve from 0.93209
# 390/390 - 21s - loss: 0.7346 - accuracy: 0.9313 - val_loss: 0.7115 - val_accuracy: 0.9425
# Epoch 215/500
#
# Epoch 00215: val_accuracy did not improve from 0.97880
#
# Epoch 00215: accuracy did not improve from 0.93209
# 390/390 - 21s - loss: 0.7322 - accuracy: 0.9319 - val_loss: 0.7137 - val_accuracy: 0.9406
# Epoch 216/500
#
# Epoch 00216: val_accuracy did not improve from 0.97880
#
# Epoch 00216: accuracy did not improve from 0.93209
# 390/390 - 21s - loss: 0.7325 - accuracy: 0.9318 - val_loss: 0.7124 - val_accuracy: 0.9397
# Epoch 217/500
#
# Epoch 00217: val_accuracy did not improve from 0.97880
#
# Epoch 00217: accuracy improved from 0.93209 to 0.93333, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7310 - accuracy: 0.9333 - val_loss: 0.7149 - val_accuracy: 0.9398
# Epoch 218/500
#
# Epoch 00218: val_accuracy did not improve from 0.97880
#
# Epoch 00218: accuracy improved from 0.93333 to 0.93441, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7274 - accuracy: 0.9344 - val_loss: 0.7138 - val_accuracy: 0.9395
# Epoch 219/500
#
# Epoch 00219: val_accuracy did not improve from 0.97880
#
# Epoch 00219: accuracy did not improve from 0.93441
# 390/390 - 21s - loss: 0.7293 - accuracy: 0.9327 - val_loss: 0.7107 - val_accuracy: 0.9408
# Epoch 220/500
#
# Epoch 00220: val_accuracy did not improve from 0.97880
#
# Epoch 00220: accuracy did not improve from 0.93441
# 390/390 - 21s - loss: 0.7249 - accuracy: 0.9329 - val_loss: 0.7112 - val_accuracy: 0.9402
# Epoch 221/500
#
# Epoch 00221: val_accuracy did not improve from 0.97880
#
# Epoch 00221: accuracy did not improve from 0.93441
# 390/390 - 21s - loss: 0.7258 - accuracy: 0.9332 - val_loss: 0.7117 - val_accuracy: 0.9401
# Epoch 222/500
#
# Epoch 00222: val_accuracy did not improve from 0.97880
#
# Epoch 00222: accuracy improved from 0.93441 to 0.93545, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7192 - accuracy: 0.9355 - val_loss: 0.7113 - val_accuracy: 0.9399
# Epoch 223/500
#
# Epoch 00223: val_accuracy did not improve from 0.97880
#
# Epoch 00223: accuracy did not improve from 0.93545
# 390/390 - 21s - loss: 0.7263 - accuracy: 0.9333 - val_loss: 0.7139 - val_accuracy: 0.9409
# Epoch 224/500
#
# Epoch 00224: val_accuracy did not improve from 0.97880
#
# Epoch 00224: accuracy did not improve from 0.93545
# 390/390 - 21s - loss: 0.7206 - accuracy: 0.9344 - val_loss: 0.7110 - val_accuracy: 0.9401
# Epoch 225/500
#
# Epoch 00225: val_accuracy did not improve from 0.97880
#
# Epoch 00225: accuracy did not improve from 0.93545
# 390/390 - 21s - loss: 0.7220 - accuracy: 0.9338 - val_loss: 0.7113 - val_accuracy: 0.9398
# Epoch 226/500
#
# Epoch 00226: val_accuracy did not improve from 0.97880
#
# Epoch 00226: accuracy did not improve from 0.93545
# 390/390 - 21s - loss: 0.7249 - accuracy: 0.9344 - val_loss: 0.7074 - val_accuracy: 0.9409
# Epoch 227/500
#
# Epoch 00227: val_accuracy did not improve from 0.97880
#
# Epoch 00227: accuracy improved from 0.93545 to 0.93624, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7197 - accuracy: 0.9362 - val_loss: 0.7077 - val_accuracy: 0.9416
# Epoch 228/500
#
# Epoch 00228: val_accuracy did not improve from 0.97880
#
# Epoch 00228: accuracy improved from 0.93624 to 0.93652, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7167 - accuracy: 0.9365 - val_loss: 0.7102 - val_accuracy: 0.9407
# Epoch 229/500
#
# Epoch 00229: val_accuracy did not improve from 0.97880
#
# Epoch 00229: accuracy did not improve from 0.93652
# 390/390 - 21s - loss: 0.7166 - accuracy: 0.9365 - val_loss: 0.7147 - val_accuracy: 0.9390
# Epoch 230/500
#
# Epoch 00230: val_accuracy did not improve from 0.97880
#
# Epoch 00230: accuracy did not improve from 0.93652
# 390/390 - 21s - loss: 0.7154 - accuracy: 0.9355 - val_loss: 0.7174 - val_accuracy: 0.9381
# Epoch 231/500
#
# Epoch 00231: val_accuracy did not improve from 0.97880
#
# Epoch 00231: accuracy did not improve from 0.93652
# 390/390 - 21s - loss: 0.7208 - accuracy: 0.9346 - val_loss: 0.7103 - val_accuracy: 0.9403
# Epoch 232/500
#
# Epoch 00232: val_accuracy did not improve from 0.97880
#
# Epoch 00232: accuracy did not improve from 0.93652
# 390/390 - 21s - loss: 0.7147 - accuracy: 0.9357 - val_loss: 0.7047 - val_accuracy: 0.9410
# Epoch 233/500
#
# Epoch 00233: val_accuracy did not improve from 0.97880
#
# Epoch 00233: accuracy did not improve from 0.93652
# 390/390 - 21s - loss: 0.7157 - accuracy: 0.9353 - val_loss: 0.7041 - val_accuracy: 0.9413
# Epoch 234/500
#
# Epoch 00234: val_accuracy did not improve from 0.97880
#
# Epoch 00234: accuracy did not improve from 0.93652
# 390/390 - 21s - loss: 0.7156 - accuracy: 0.9364 - val_loss: 0.7092 - val_accuracy: 0.9405
# Epoch 235/500
#
# Epoch 00235: val_accuracy did not improve from 0.97880
#
# Epoch 00235: accuracy did not improve from 0.93652
# 390/390 - 21s - loss: 0.7175 - accuracy: 0.9361 - val_loss: 0.7032 - val_accuracy: 0.9424
# Epoch 236/500
#
# Epoch 00236: val_accuracy did not improve from 0.97880
#
# Epoch 00236: accuracy improved from 0.93652 to 0.93708, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7144 - accuracy: 0.9371 - val_loss: 0.7106 - val_accuracy: 0.9401
# Epoch 237/500
#
# Epoch 00237: val_accuracy did not improve from 0.97880
#
# Epoch 00237: accuracy improved from 0.93708 to 0.93760, saving model to my_train_model1.hdf5
# 390/390 - 22s - loss: 0.7120 - accuracy: 0.9376 - val_loss: 0.7061 - val_accuracy: 0.9410
# Epoch 238/500
#
# Epoch 00238: val_accuracy did not improve from 0.97880
#
# Epoch 00238: accuracy did not improve from 0.93760
# 390/390 - 21s - loss: 0.7132 - accuracy: 0.9375 - val_loss: 0.7052 - val_accuracy: 0.9411
# Epoch 239/500
#
# Epoch 00239: val_accuracy did not improve from 0.97880
#
# Epoch 00239: accuracy did not improve from 0.93760
# 390/390 - 21s - loss: 0.7134 - accuracy: 0.9372 - val_loss: 0.7058 - val_accuracy: 0.9410
# Epoch 240/500
#
# Epoch 00240: val_accuracy did not improve from 0.97880
#
# Epoch 00240: accuracy did not improve from 0.93760
# 390/390 - 21s - loss: 0.7153 - accuracy: 0.9363 - val_loss: 0.7064 - val_accuracy: 0.9416
# Epoch 241/500
#
# Epoch 00241: val_accuracy did not improve from 0.97880
#
# Epoch 00241: accuracy did not improve from 0.93760
# 390/390 - 21s - loss: 0.7126 - accuracy: 0.9368 - val_loss: 0.7078 - val_accuracy: 0.9399
# Epoch 242/500
#
# Epoch 00242: val_accuracy did not improve from 0.97880
#
# Epoch 00242: accuracy did not improve from 0.93760
# 390/390 - 21s - loss: 0.7131 - accuracy: 0.9368 - val_loss: 0.7093 - val_accuracy: 0.9392
# Epoch 243/500
#
# Epoch 00243: val_accuracy did not improve from 0.97880
#
# Epoch 00243: accuracy did not improve from 0.93760
# 390/390 - 21s - loss: 0.7160 - accuracy: 0.9353 - val_loss: 0.7029 - val_accuracy: 0.9416
# Epoch 244/500
#
# Epoch 00244: val_accuracy did not improve from 0.97880
#
# Epoch 00244: accuracy improved from 0.93760 to 0.93788, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7103 - accuracy: 0.9379 - val_loss: 0.7041 - val_accuracy: 0.9420
# Epoch 245/500
#
# Epoch 00245: val_accuracy did not improve from 0.97880
#
# Epoch 00245: accuracy did not improve from 0.93788
# 390/390 - 21s - loss: 0.7099 - accuracy: 0.9372 - val_loss: 0.7032 - val_accuracy: 0.9421
# Epoch 246/500
#
# Epoch 00246: val_accuracy did not improve from 0.97880
#
# Epoch 00246: accuracy did not improve from 0.93788
# 390/390 - 21s - loss: 0.7118 - accuracy: 0.9370 - val_loss: 0.7048 - val_accuracy: 0.9404
# Epoch 247/500
#
# Epoch 00247: val_accuracy did not improve from 0.97880
#
# Epoch 00247: accuracy did not improve from 0.93788
# 390/390 - 21s - loss: 0.7061 - accuracy: 0.9377 - val_loss: 0.7071 - val_accuracy: 0.9398
# Epoch 248/500
#
# Epoch 00248: val_accuracy did not improve from 0.97880
#
# Epoch 00248: accuracy did not improve from 0.93788
# 390/390 - 21s - loss: 0.7108 - accuracy: 0.9356 - val_loss: 0.7081 - val_accuracy: 0.9400
# Epoch 249/500
#
# Epoch 00249: val_accuracy did not improve from 0.97880
#
# Epoch 00249: accuracy did not improve from 0.93788
# 390/390 - 21s - loss: 0.7086 - accuracy: 0.9372 - val_loss: 0.7074 - val_accuracy: 0.9398
# Epoch 250/500
#
# Epoch 00250: val_accuracy did not improve from 0.97880
#
# Epoch 00250: accuracy improved from 0.93788 to 0.93822, saving model to my_train_model1.hdf5
# 390/390 - 22s - loss: 0.7075 - accuracy: 0.9382 - val_loss: 0.7065 - val_accuracy: 0.9412
# Epoch 251/500
#
# Epoch 00251: val_accuracy did not improve from 0.97880
#
# Epoch 00251: accuracy did not improve from 0.93822
# 390/390 - 21s - loss: 0.7104 - accuracy: 0.9368 - val_loss: 0.7079 - val_accuracy: 0.9403
# Epoch 252/500
#
# Epoch 00252: val_accuracy did not improve from 0.97880
#
# Epoch 00252: accuracy did not improve from 0.93822
# 390/390 - 21s - loss: 0.7150 - accuracy: 0.9359 - val_loss: 0.7049 - val_accuracy: 0.9413
# Epoch 253/500
#
# Epoch 00253: val_accuracy did not improve from 0.97880
#
# Epoch 00253: accuracy improved from 0.93822 to 0.93906, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7041 - accuracy: 0.9391 - val_loss: 0.7076 - val_accuracy: 0.9399
# Epoch 254/500
#
# Epoch 00254: val_accuracy did not improve from 0.97880
#
# Epoch 00254: accuracy did not improve from 0.93906
# 390/390 - 21s - loss: 0.7091 - accuracy: 0.9379 - val_loss: 0.7049 - val_accuracy: 0.9407
# Epoch 255/500
#
# Epoch 00255: val_accuracy did not improve from 0.97880
#
# Epoch 00255: accuracy did not improve from 0.93906
# 390/390 - 21s - loss: 0.7073 - accuracy: 0.9384 - val_loss: 0.7102 - val_accuracy: 0.9395
# Epoch 256/500
#
# Epoch 00256: val_accuracy did not improve from 0.97880
#
# Epoch 00256: accuracy did not improve from 0.93906
# 390/390 - 21s - loss: 0.7057 - accuracy: 0.9386 - val_loss: 0.7033 - val_accuracy: 0.9413
# Epoch 257/500
#
# Epoch 00257: val_accuracy did not improve from 0.97880
#
# Epoch 00257: accuracy improved from 0.93906 to 0.93957, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.7039 - accuracy: 0.9396 - val_loss: 0.7103 - val_accuracy: 0.9389
# Epoch 258/500
#
# Epoch 00258: val_accuracy did not improve from 0.97880
#
# Epoch 00258: accuracy did not improve from 0.93957
# 390/390 - 21s - loss: 0.7060 - accuracy: 0.9383 - val_loss: 0.7070 - val_accuracy: 0.9400
# Epoch 259/500
#
# Epoch 00259: val_accuracy did not improve from 0.97880
#
# Epoch 00259: accuracy did not improve from 0.93957
# 390/390 - 21s - loss: 0.7063 - accuracy: 0.9384 - val_loss: 0.7067 - val_accuracy: 0.9402
# Epoch 260/500
#
# Epoch 00260: val_accuracy did not improve from 0.97880
#
# Epoch 00260: accuracy did not improve from 0.93957
# 390/390 - 21s - loss: 0.7058 - accuracy: 0.9389 - val_loss: 0.7063 - val_accuracy: 0.9397
# Epoch 261/500
#
# Epoch 00261: val_accuracy did not improve from 0.97880
#
# Epoch 00261: accuracy did not improve from 0.93957
# 390/390 - 21s - loss: 0.7074 - accuracy: 0.9369 - val_loss: 0.7058 - val_accuracy: 0.9399
# Epoch 262/500
#
# Epoch 00262: val_accuracy did not improve from 0.97880
#
# Epoch 00262: accuracy did not improve from 0.93957
# 390/390 - 21s - loss: 0.7019 - accuracy: 0.9395 - val_loss: 0.7075 - val_accuracy: 0.9398
# Epoch 263/500
#
# Epoch 00263: val_accuracy did not improve from 0.97880
#
# Epoch 00263: accuracy improved from 0.93957 to 0.94067, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.6985 - accuracy: 0.9407 - val_loss: 0.7072 - val_accuracy: 0.9400
# Epoch 264/500
#
# Epoch 00264: val_accuracy did not improve from 0.97880
#
# Epoch 00264: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7073 - accuracy: 0.9382 - val_loss: 0.7043 - val_accuracy: 0.9406
# Epoch 265/500
#
# Epoch 00265: val_accuracy did not improve from 0.97880
#
# Epoch 00265: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7036 - accuracy: 0.9392 - val_loss: 0.7065 - val_accuracy: 0.9405
# Epoch 266/500
#
# Epoch 00266: val_accuracy did not improve from 0.97880
#
# Epoch 00266: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.6996 - accuracy: 0.9399 - val_loss: 0.7117 - val_accuracy: 0.9393
# Epoch 267/500
#
# Epoch 00267: val_accuracy did not improve from 0.97880
#
# Epoch 00267: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7022 - accuracy: 0.9386 - val_loss: 0.7086 - val_accuracy: 0.9398
# Epoch 268/500
#
# Epoch 00268: val_accuracy did not improve from 0.97880
#
# Epoch 00268: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7056 - accuracy: 0.9380 - val_loss: 0.7042 - val_accuracy: 0.9406
# Epoch 269/500
#
# Epoch 00269: val_accuracy did not improve from 0.97880
#
# Epoch 00269: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7073 - accuracy: 0.9370 - val_loss: 0.7057 - val_accuracy: 0.9403
# Epoch 270/500
#
# Epoch 00270: val_accuracy did not improve from 0.97880
#
# Epoch 00270: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7054 - accuracy: 0.9376 - val_loss: 0.7066 - val_accuracy: 0.9401
# Epoch 271/500
#
# Epoch 00271: val_accuracy did not improve from 0.97880
#
# Epoch 00271: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7013 - accuracy: 0.9395 - val_loss: 0.7061 - val_accuracy: 0.9401
# Epoch 272/500
#
# Epoch 00272: val_accuracy did not improve from 0.97880
#
# Epoch 00272: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7044 - accuracy: 0.9378 - val_loss: 0.7088 - val_accuracy: 0.9395
# Epoch 273/500
#
# Epoch 00273: val_accuracy did not improve from 0.97880
#
# Epoch 00273: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.6999 - accuracy: 0.9394 - val_loss: 0.7032 - val_accuracy: 0.9411
# Epoch 274/500
#
# Epoch 00274: val_accuracy did not improve from 0.97880
#
# Epoch 00274: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7061 - accuracy: 0.9376 - val_loss: 0.7058 - val_accuracy: 0.9401
# Epoch 275/500
#
# Epoch 00275: val_accuracy did not improve from 0.97880
#
# Epoch 00275: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7011 - accuracy: 0.9402 - val_loss: 0.7051 - val_accuracy: 0.9400
# Epoch 276/500
#
# Epoch 00276: val_accuracy did not improve from 0.97880
#
# Epoch 00276: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7008 - accuracy: 0.9398 - val_loss: 0.7046 - val_accuracy: 0.9408
# Epoch 277/500
#
# Epoch 00277: val_accuracy did not improve from 0.97880
#
# Epoch 00277: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7052 - accuracy: 0.9382 - val_loss: 0.7071 - val_accuracy: 0.9395
# Epoch 278/500
#
# Epoch 00278: val_accuracy did not improve from 0.97880
#
# Epoch 00278: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7020 - accuracy: 0.9397 - val_loss: 0.7042 - val_accuracy: 0.9411
# Epoch 279/500
#
# Epoch 00279: val_accuracy did not improve from 0.97880
#
# Epoch 00279: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7010 - accuracy: 0.9403 - val_loss: 0.7079 - val_accuracy: 0.9400
# Epoch 280/500
#
# Epoch 00280: val_accuracy did not improve from 0.97880
#
# Epoch 00280: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7084 - accuracy: 0.9368 - val_loss: 0.7079 - val_accuracy: 0.9394
# Epoch 281/500
#
# Epoch 00281: val_accuracy did not improve from 0.97880
#
# Epoch 00281: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7025 - accuracy: 0.9390 - val_loss: 0.7058 - val_accuracy: 0.9398
# Epoch 282/500
#
# Epoch 00282: val_accuracy did not improve from 0.97880
#
# Epoch 00282: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7017 - accuracy: 0.9383 - val_loss: 0.7036 - val_accuracy: 0.9403
# Epoch 283/500
#
# Epoch 00283: val_accuracy did not improve from 0.97880
#
# Epoch 00283: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7000 - accuracy: 0.9400 - val_loss: 0.7056 - val_accuracy: 0.9404
# Epoch 284/500
#
# Epoch 00284: val_accuracy did not improve from 0.97880
#
# Epoch 00284: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7071 - accuracy: 0.9376 - val_loss: 0.7093 - val_accuracy: 0.9395
# Epoch 285/500
#
# Epoch 00285: val_accuracy did not improve from 0.97880
#
# Epoch 00285: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7016 - accuracy: 0.9389 - val_loss: 0.7062 - val_accuracy: 0.9398
# Epoch 286/500
#
# Epoch 00286: val_accuracy did not improve from 0.97880
#
# Epoch 00286: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7021 - accuracy: 0.9379 - val_loss: 0.7071 - val_accuracy: 0.9401
# Epoch 287/500
#
# Epoch 00287: val_accuracy did not improve from 0.97880
#
# Epoch 00287: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7043 - accuracy: 0.9395 - val_loss: 0.7099 - val_accuracy: 0.9395
# Epoch 288/500
#
# Epoch 00288: val_accuracy did not improve from 0.97880
#
# Epoch 00288: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7021 - accuracy: 0.9402 - val_loss: 0.7067 - val_accuracy: 0.9401
# Epoch 289/500
#
# Epoch 00289: val_accuracy did not improve from 0.97880
#
# Epoch 00289: accuracy did not improve from 0.94067
# 390/390 - 21s - loss: 0.7032 - accuracy: 0.9385 - val_loss: 0.7052 - val_accuracy: 0.9405
# Epoch 290/500
#
# Epoch 00290: val_accuracy did not improve from 0.97880
#
# Epoch 00290: accuracy improved from 0.94067 to 0.94103, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.6962 - accuracy: 0.9410 - val_loss: 0.7051 - val_accuracy: 0.9400
# Epoch 291/500
#
# Epoch 00291: val_accuracy did not improve from 0.97880
#
# Epoch 00291: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.6990 - accuracy: 0.9396 - val_loss: 0.7038 - val_accuracy: 0.9413
# Epoch 292/500
#
# Epoch 00292: val_accuracy did not improve from 0.97880
#
# Epoch 00292: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7013 - accuracy: 0.9386 - val_loss: 0.7003 - val_accuracy: 0.9417
# Epoch 293/500
#
# Epoch 00293: val_accuracy did not improve from 0.97880
#
# Epoch 00293: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7027 - accuracy: 0.9398 - val_loss: 0.7067 - val_accuracy: 0.9407
# Epoch 294/500
#
# Epoch 00294: val_accuracy did not improve from 0.97880
#
# Epoch 00294: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7010 - accuracy: 0.9399 - val_loss: 0.7029 - val_accuracy: 0.9408
# Epoch 295/500
#
# Epoch 00295: val_accuracy did not improve from 0.97880
#
# Epoch 00295: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.6987 - accuracy: 0.9407 - val_loss: 0.7082 - val_accuracy: 0.9386
# Epoch 296/500
#
# Epoch 00296: val_accuracy did not improve from 0.97880
#
# Epoch 00296: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7005 - accuracy: 0.9408 - val_loss: 0.7079 - val_accuracy: 0.9396
# Epoch 297/500
#
# Epoch 00297: val_accuracy did not improve from 0.97880
#
# Epoch 00297: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7025 - accuracy: 0.9388 - val_loss: 0.7039 - val_accuracy: 0.9407
# Epoch 298/500
#
# Epoch 00298: val_accuracy did not improve from 0.97880
#
# Epoch 00298: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7022 - accuracy: 0.9389 - val_loss: 0.7051 - val_accuracy: 0.9408
# Epoch 299/500
#
# Epoch 00299: val_accuracy did not improve from 0.97880
#
# Epoch 00299: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7019 - accuracy: 0.9391 - val_loss: 0.7057 - val_accuracy: 0.9398
# Epoch 300/500
#
# Epoch 00300: val_accuracy did not improve from 0.97880
#
# Epoch 00300: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7012 - accuracy: 0.9390 - val_loss: 0.7065 - val_accuracy: 0.9402
# Epoch 301/500
#
# Epoch 00301: val_accuracy did not improve from 0.97880
#
# Epoch 00301: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.6994 - accuracy: 0.9396 - val_loss: 0.7033 - val_accuracy: 0.9404
# Epoch 302/500
#
# Epoch 00302: val_accuracy did not improve from 0.97880
#
# Epoch 00302: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.6971 - accuracy: 0.9407 - val_loss: 0.7064 - val_accuracy: 0.9402
# Epoch 303/500
#
# Epoch 00303: val_accuracy did not improve from 0.97880
#
# Epoch 00303: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.6965 - accuracy: 0.9410 - val_loss: 0.7025 - val_accuracy: 0.9414
# Epoch 304/500
#
# Epoch 00304: val_accuracy did not improve from 0.97880
#
# Epoch 00304: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7012 - accuracy: 0.9396 - val_loss: 0.7056 - val_accuracy: 0.9396
# Epoch 305/500
#
# Epoch 00305: val_accuracy did not improve from 0.97880
#
# Epoch 00305: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7009 - accuracy: 0.9392 - val_loss: 0.7061 - val_accuracy: 0.9405
# Epoch 306/500
#
# Epoch 00306: val_accuracy did not improve from 0.97880
#
# Epoch 00306: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.6983 - accuracy: 0.9401 - val_loss: 0.7057 - val_accuracy: 0.9406
# Epoch 307/500
#
# Epoch 00307: val_accuracy did not improve from 0.97880
#
# Epoch 00307: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.6977 - accuracy: 0.9404 - val_loss: 0.7042 - val_accuracy: 0.9413
# Epoch 308/500
#
# Epoch 00308: val_accuracy did not improve from 0.97880
#
# Epoch 00308: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7023 - accuracy: 0.9394 - val_loss: 0.7101 - val_accuracy: 0.9390
# Epoch 309/500
#
# Epoch 00309: val_accuracy did not improve from 0.97880
#
# Epoch 00309: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7020 - accuracy: 0.9395 - val_loss: 0.7044 - val_accuracy: 0.9407
# Epoch 310/500
#
# Epoch 00310: val_accuracy did not improve from 0.97880
#
# Epoch 00310: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7002 - accuracy: 0.9387 - val_loss: 0.7054 - val_accuracy: 0.9406
# Epoch 311/500
#
# Epoch 00311: val_accuracy did not improve from 0.97880
#
# Epoch 00311: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7002 - accuracy: 0.9392 - val_loss: 0.7075 - val_accuracy: 0.9394
# Epoch 312/500
#
# Epoch 00312: val_accuracy did not improve from 0.97880
#
# Epoch 00312: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7001 - accuracy: 0.9406 - val_loss: 0.7030 - val_accuracy: 0.9411
# Epoch 313/500
#
# Epoch 00313: val_accuracy did not improve from 0.97880
#
# Epoch 00313: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.6994 - accuracy: 0.9388 - val_loss: 0.7067 - val_accuracy: 0.9402
# Epoch 314/500
#
# Epoch 00314: val_accuracy did not improve from 0.97880
#
# Epoch 00314: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.6986 - accuracy: 0.9390 - val_loss: 0.7056 - val_accuracy: 0.9402
# Epoch 315/500
#
# Epoch 00315: val_accuracy did not improve from 0.97880
#
# Epoch 00315: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7012 - accuracy: 0.9389 - val_loss: 0.7055 - val_accuracy: 0.9406
# Epoch 316/500
#
# Epoch 00316: val_accuracy did not improve from 0.97880
#
# Epoch 00316: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7024 - accuracy: 0.9399 - val_loss: 0.7066 - val_accuracy: 0.9392
# Epoch 317/500
#
# Epoch 00317: val_accuracy did not improve from 0.97880
#
# Epoch 00317: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.6997 - accuracy: 0.9404 - val_loss: 0.7066 - val_accuracy: 0.9404
# Epoch 318/500
#
# Epoch 00318: val_accuracy did not improve from 0.97880
#
# Epoch 00318: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.6998 - accuracy: 0.9397 - val_loss: 0.7034 - val_accuracy: 0.9407
# Epoch 319/500
#
# Epoch 00319: val_accuracy did not improve from 0.97880
#
# Epoch 00319: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.6998 - accuracy: 0.9391 - val_loss: 0.7060 - val_accuracy: 0.9395
# Epoch 320/500
#
# Epoch 00320: val_accuracy did not improve from 0.97880
#
# Epoch 00320: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.6993 - accuracy: 0.9384 - val_loss: 0.7034 - val_accuracy: 0.9410
# Epoch 321/500
#
# Epoch 00321: val_accuracy did not improve from 0.97880
#
# Epoch 00321: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.6964 - accuracy: 0.9400 - val_loss: 0.7055 - val_accuracy: 0.9397
# Epoch 322/500
#
# Epoch 00322: val_accuracy did not improve from 0.97880
#
# Epoch 00322: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.6977 - accuracy: 0.9401 - val_loss: 0.7017 - val_accuracy: 0.9412
# Epoch 323/500
#
# Epoch 00323: val_accuracy did not improve from 0.97880
#
# Epoch 00323: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7024 - accuracy: 0.9380 - val_loss: 0.7041 - val_accuracy: 0.9409
# Epoch 324/500
#
# Epoch 00324: val_accuracy did not improve from 0.97880
#
# Epoch 00324: accuracy did not improve from 0.94103
# 390/390 - 21s - loss: 0.7003 - accuracy: 0.9399 - val_loss: 0.7080 - val_accuracy: 0.9398
# Epoch 325/500
#
# Epoch 00325: val_accuracy did not improve from 0.97880
#
# Epoch 00325: accuracy improved from 0.94103 to 0.94141, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.6946 - accuracy: 0.9414 - val_loss: 0.7054 - val_accuracy: 0.9399
# Epoch 326/500
#
# Epoch 00326: val_accuracy did not improve from 0.97880
#
# Epoch 00326: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6973 - accuracy: 0.9407 - val_loss: 0.7070 - val_accuracy: 0.9393
# Epoch 327/500
#
# Epoch 00327: val_accuracy did not improve from 0.97880
#
# Epoch 00327: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.7009 - accuracy: 0.9396 - val_loss: 0.7063 - val_accuracy: 0.9400
# Epoch 328/500
#
# Epoch 00328: val_accuracy did not improve from 0.97880
#
# Epoch 00328: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6971 - accuracy: 0.9411 - val_loss: 0.7069 - val_accuracy: 0.9389
# Epoch 329/500
#
# Epoch 00329: val_accuracy did not improve from 0.97880
#
# Epoch 00329: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.7050 - accuracy: 0.9376 - val_loss: 0.7054 - val_accuracy: 0.9408
# Epoch 330/500
#
# Epoch 00330: val_accuracy did not improve from 0.97880
#
# Epoch 00330: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6992 - accuracy: 0.9405 - val_loss: 0.7052 - val_accuracy: 0.9405
# Epoch 331/500
#
# Epoch 00331: val_accuracy did not improve from 0.97880
#
# Epoch 00331: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6996 - accuracy: 0.9404 - val_loss: 0.7042 - val_accuracy: 0.9410
# Epoch 332/500
#
# Epoch 00332: val_accuracy did not improve from 0.97880
#
# Epoch 00332: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6986 - accuracy: 0.9408 - val_loss: 0.7071 - val_accuracy: 0.9400
# Epoch 333/500
#
# Epoch 00333: val_accuracy did not improve from 0.97880
#
# Epoch 00333: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6993 - accuracy: 0.9399 - val_loss: 0.7043 - val_accuracy: 0.9403
# Epoch 334/500
#
# Epoch 00334: val_accuracy did not improve from 0.97880
#
# Epoch 00334: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6945 - accuracy: 0.9399 - val_loss: 0.7043 - val_accuracy: 0.9404
# Epoch 335/500
#
# Epoch 00335: val_accuracy did not improve from 0.97880
#
# Epoch 00335: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6981 - accuracy: 0.9407 - val_loss: 0.7055 - val_accuracy: 0.9399
# Epoch 336/500
#
# Epoch 00336: val_accuracy did not improve from 0.97880
#
# Epoch 00336: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6971 - accuracy: 0.9407 - val_loss: 0.7050 - val_accuracy: 0.9404
# Epoch 337/500
#
# Epoch 00337: val_accuracy did not improve from 0.97880
#
# Epoch 00337: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.7062 - accuracy: 0.9371 - val_loss: 0.7040 - val_accuracy: 0.9401
# Epoch 338/500
#
# Epoch 00338: val_accuracy did not improve from 0.97880
#
# Epoch 00338: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6971 - accuracy: 0.9405 - val_loss: 0.7088 - val_accuracy: 0.9393
# Epoch 339/500
#
# Epoch 00339: val_accuracy did not improve from 0.97880
#
# Epoch 00339: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.7002 - accuracy: 0.9396 - val_loss: 0.7038 - val_accuracy: 0.9401
# Epoch 340/500
#
# Epoch 00340: val_accuracy did not improve from 0.97880
#
# Epoch 00340: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6980 - accuracy: 0.9397 - val_loss: 0.7062 - val_accuracy: 0.9401
# Epoch 341/500
#
# Epoch 00341: val_accuracy did not improve from 0.97880
#
# Epoch 00341: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.7009 - accuracy: 0.9395 - val_loss: 0.7084 - val_accuracy: 0.9386
# Epoch 342/500
#
# Epoch 00342: val_accuracy did not improve from 0.97880
#
# Epoch 00342: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6975 - accuracy: 0.9386 - val_loss: 0.7043 - val_accuracy: 0.9406
# Epoch 343/500
#
# Epoch 00343: val_accuracy did not improve from 0.97880
#
# Epoch 00343: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6959 - accuracy: 0.9413 - val_loss: 0.7036 - val_accuracy: 0.9409
# Epoch 344/500
#
# Epoch 00344: val_accuracy did not improve from 0.97880
#
# Epoch 00344: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6983 - accuracy: 0.9393 - val_loss: 0.7045 - val_accuracy: 0.9412
# Epoch 345/500
#
# Epoch 00345: val_accuracy did not improve from 0.97880
#
# Epoch 00345: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.7002 - accuracy: 0.9385 - val_loss: 0.7065 - val_accuracy: 0.9409
# Epoch 346/500
#
# Epoch 00346: val_accuracy did not improve from 0.97880
#
# Epoch 00346: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6986 - accuracy: 0.9392 - val_loss: 0.7068 - val_accuracy: 0.9397
# Epoch 347/500
#
# Epoch 00347: val_accuracy did not improve from 0.97880
#
# Epoch 00347: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.7002 - accuracy: 0.9397 - val_loss: 0.7056 - val_accuracy: 0.9398
# Epoch 348/500
#
# Epoch 00348: val_accuracy did not improve from 0.97880
#
# Epoch 00348: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6997 - accuracy: 0.9388 - val_loss: 0.7057 - val_accuracy: 0.9394
# Epoch 349/500
#
# Epoch 00349: val_accuracy did not improve from 0.97880
#
# Epoch 00349: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6972 - accuracy: 0.9400 - val_loss: 0.7072 - val_accuracy: 0.9391
# Epoch 350/500
#
# Epoch 00350: val_accuracy did not improve from 0.97880
#
# Epoch 00350: accuracy did not improve from 0.94141
# 390/390 - 21s - loss: 0.6973 - accuracy: 0.9396 - val_loss: 0.7053 - val_accuracy: 0.9401
# Epoch 351/500
#
# Epoch 00351: val_accuracy did not improve from 0.97880
#
# Epoch 00351: accuracy improved from 0.94141 to 0.94203, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.6923 - accuracy: 0.9420 - val_loss: 0.7051 - val_accuracy: 0.9404
# Epoch 352/500
#
# Epoch 00352: val_accuracy did not improve from 0.97880
#
# Epoch 00352: accuracy did not improve from 0.94203
# 390/390 - 21s - loss: 0.6988 - accuracy: 0.9397 - val_loss: 0.7052 - val_accuracy: 0.9400
# Epoch 353/500
#
# Epoch 00353: val_accuracy did not improve from 0.97880
#
# Epoch 00353: accuracy did not improve from 0.94203
# 390/390 - 21s - loss: 0.7016 - accuracy: 0.9382 - val_loss: 0.7039 - val_accuracy: 0.9404
# Epoch 354/500
#
# Epoch 00354: val_accuracy did not improve from 0.97880
#
# Epoch 00354: accuracy did not improve from 0.94203
# 390/390 - 21s - loss: 0.7015 - accuracy: 0.9402 - val_loss: 0.7063 - val_accuracy: 0.9397
# Epoch 355/500
#
# Epoch 00355: val_accuracy did not improve from 0.97880
#
# Epoch 00355: accuracy did not improve from 0.94203
# 390/390 - 21s - loss: 0.7027 - accuracy: 0.9391 - val_loss: 0.7071 - val_accuracy: 0.9399
# Epoch 356/500
#
# Epoch 00356: val_accuracy did not improve from 0.97880
#
# Epoch 00356: accuracy did not improve from 0.94203
# 390/390 - 21s - loss: 0.7003 - accuracy: 0.9401 - val_loss: 0.7084 - val_accuracy: 0.9397
# Epoch 357/500
#
# Epoch 00357: val_accuracy did not improve from 0.97880
#
# Epoch 00357: accuracy did not improve from 0.94203
# 390/390 - 21s - loss: 0.6989 - accuracy: 0.9408 - val_loss: 0.7072 - val_accuracy: 0.9390
# Epoch 358/500
#
# Epoch 00358: val_accuracy did not improve from 0.97880
#
# Epoch 00358: accuracy did not improve from 0.94203
# 390/390 - 21s - loss: 0.6920 - accuracy: 0.9415 - val_loss: 0.7055 - val_accuracy: 0.9400
# Epoch 359/500
#
# Epoch 00359: val_accuracy did not improve from 0.97880
#
# Epoch 00359: accuracy did not improve from 0.94203
# 390/390 - 21s - loss: 0.7022 - accuracy: 0.9389 - val_loss: 0.7049 - val_accuracy: 0.9400
# Epoch 360/500
#
# Epoch 00360: val_accuracy did not improve from 0.97880
#
# Epoch 00360: accuracy did not improve from 0.94203
# 390/390 - 21s - loss: 0.6972 - accuracy: 0.9405 - val_loss: 0.7109 - val_accuracy: 0.9387
# Epoch 361/500
#
# Epoch 00361: val_accuracy did not improve from 0.97880
#
# Epoch 00361: accuracy did not improve from 0.94203
# 390/390 - 21s - loss: 0.7010 - accuracy: 0.9394 - val_loss: 0.7069 - val_accuracy: 0.9402
# Epoch 362/500
#
# Epoch 00362: val_accuracy did not improve from 0.97880
#
# Epoch 00362: accuracy did not improve from 0.94203
# 390/390 - 21s - loss: 0.7017 - accuracy: 0.9399 - val_loss: 0.7039 - val_accuracy: 0.9410
# Epoch 363/500
#
# Epoch 00363: val_accuracy did not improve from 0.97880
#
# Epoch 00363: accuracy did not improve from 0.94203
# 390/390 - 21s - loss: 0.6953 - accuracy: 0.9414 - val_loss: 0.7041 - val_accuracy: 0.9407
# Epoch 364/500
#
# Epoch 00364: val_accuracy did not improve from 0.97880
#
# Epoch 00364: accuracy did not improve from 0.94203
# 390/390 - 21s - loss: 0.6984 - accuracy: 0.9394 - val_loss: 0.7062 - val_accuracy: 0.9394
# Epoch 365/500
#
# Epoch 00365: val_accuracy did not improve from 0.97880
#
# Epoch 00365: accuracy improved from 0.94203 to 0.94207, saving model to my_train_model1.hdf5
# 390/390 - 21s - loss: 0.6941 - accuracy: 0.9421 - val_loss: 0.7052 - val_accuracy: 0.9402
# Epoch 366/500
#
# Epoch 00366: val_accuracy did not improve from 0.97880
#
# Epoch 00366: accuracy did not improve from 0.94207
# 390/390 - 21s - loss: 0.6996 - accuracy: 0.9399 - val_loss: 0.7056 - val_accuracy: 0.9403
# Epoch 367/500
#
# Epoch 00367: val_accuracy did not improve from 0.97880
#
# Epoch 00367: accuracy did not improve from 0.94207
# 390/390 - 21s - loss: 0.6988 - accuracy: 0.9391 - val_loss: 0.7050 - val_accuracy: 0.9402
# Epoch 368/500
#
# Epoch 00368: val_accuracy did not improve from 0.97880
#
# Epoch 00368: accuracy did not improve from 0.94207
# 390/390 - 21s - loss: 0.7027 - accuracy: 0.9404 - val_loss: 0.7042 - val_accuracy: 0.9401
# Epoch 369/500
#
# Epoch 00369: val_accuracy did not improve from 0.97880
#
# Epoch 00369: accuracy did not improve from 0.94207
# 390/390 - 21s - loss: 0.7027 - accuracy: 0.9380 - val_loss: 0.7087 - val_accuracy: 0.9390
# Epoch 370/500
#
# Epoch 00370: val_accuracy did not improve from 0.97880
#
# Epoch 00370: accuracy did not improve from 0.94207
# ...
# Epoch 426/500
#
# Epoch 00426: val_accuracy did not improve from 0.97880
#
# Epoch 00426: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6958 - accuracy: 0.9414 - val_loss: 0.7090 - val_accuracy: 0.9387
# Epoch 427/500
#
# Epoch 00427: val_accuracy did not improve from 0.97880
#
# Epoch 00427: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6974 - accuracy: 0.9405 - val_loss: 0.7037 - val_accuracy: 0.9402
# Epoch 428/500
#
# Epoch 00428: val_accuracy did not improve from 0.97880
#
# Epoch 00428: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6958 - accuracy: 0.9405 - val_loss: 0.7055 - val_accuracy: 0.9407
# Epoch 429/500
#
# Epoch 00429: val_accuracy did not improve from 0.97880
#
# Epoch 00429: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7023 - accuracy: 0.9389 - val_loss: 0.7051 - val_accuracy: 0.9398
# Epoch 430/500
#
# Epoch 00430: val_accuracy did not improve from 0.97880
#
# Epoch 00430: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6952 - accuracy: 0.9411 - val_loss: 0.7054 - val_accuracy: 0.9399
# Epoch 431/500
#
# Epoch 00431: val_accuracy did not improve from 0.97880
#
# Epoch 00431: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6985 - accuracy: 0.9394 - val_loss: 0.7065 - val_accuracy: 0.9391
# Epoch 432/500
#
# Epoch 00432: val_accuracy did not improve from 0.97880
#
# Epoch 00432: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6996 - accuracy: 0.9387 - val_loss: 0.7076 - val_accuracy: 0.9396
# Epoch 433/500
#
# Epoch 00433: val_accuracy did not improve from 0.97880
#
# Epoch 00433: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6991 - accuracy: 0.9397 - val_loss: 0.7113 - val_accuracy: 0.9382
# Epoch 434/500
#
# Epoch 00434: val_accuracy did not improve from 0.97880
#
# Epoch 00434: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7023 - accuracy: 0.9383 - val_loss: 0.7084 - val_accuracy: 0.9389
# Epoch 435/500
#
# Epoch 00435: val_accuracy did not improve from 0.97880
#
# Epoch 00435: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6971 - accuracy: 0.9393 - val_loss: 0.7056 - val_accuracy: 0.9406
# Epoch 436/500
#
# Epoch 00436: val_accuracy did not improve from 0.97880
#
# Epoch 00436: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7015 - accuracy: 0.9398 - val_loss: 0.7052 - val_accuracy: 0.9406
# Epoch 437/500
#
# Epoch 00437: val_accuracy did not improve from 0.97880
#
# Epoch 00437: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7015 - accuracy: 0.9403 - val_loss: 0.7115 - val_accuracy: 0.9391
# Epoch 438/500
#
# Epoch 00438: val_accuracy did not improve from 0.97880
#
# Epoch 00438: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6997 - accuracy: 0.9393 - val_loss: 0.7074 - val_accuracy: 0.9392
# Epoch 439/500
#
# Epoch 00439: val_accuracy did not improve from 0.97880
#
# Epoch 00439: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6953 - accuracy: 0.9396 - val_loss: 0.7074 - val_accuracy: 0.9393
# Epoch 440/500
#
# Epoch 00440: val_accuracy did not improve from 0.97880
#
# Epoch 00440: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6986 - accuracy: 0.9396 - val_loss: 0.7054 - val_accuracy: 0.9392
# Epoch 441/500
#
# Epoch 00441: val_accuracy did not improve from 0.97880
#
# Epoch 00441: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6978 - accuracy: 0.9401 - val_loss: 0.7023 - val_accuracy: 0.9414
# Epoch 442/500
#
# Epoch 00442: val_accuracy did not improve from 0.97880
#
# Epoch 00442: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6968 - accuracy: 0.9401 - val_loss: 0.7066 - val_accuracy: 0.9400
# Epoch 443/500
#
# Epoch 00443: val_accuracy did not improve from 0.97880
#
# Epoch 00443: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7004 - accuracy: 0.9397 - val_loss: 0.7069 - val_accuracy: 0.9404
# Epoch 444/500
#
# Epoch 00444: val_accuracy did not improve from 0.97880
#
# Epoch 00444: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6964 - accuracy: 0.9407 - val_loss: 0.7039 - val_accuracy: 0.9403
# Epoch 445/500
#
# Epoch 00445: val_accuracy did not improve from 0.97880
#
# Epoch 00445: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6954 - accuracy: 0.9409 - val_loss: 0.7046 - val_accuracy: 0.9399
# Epoch 446/500
#
# Epoch 00446: val_accuracy did not improve from 0.97880
#
# Epoch 00446: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6972 - accuracy: 0.9408 - val_loss: 0.7063 - val_accuracy: 0.9399
# Epoch 447/500
#
# Epoch 00447: val_accuracy did not improve from 0.97880
#
# Epoch 00447: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7000 - accuracy: 0.9394 - val_loss: 0.7058 - val_accuracy: 0.9401
# Epoch 448/500
#
# Epoch 00448: val_accuracy did not improve from 0.97880
#
# Epoch 00448: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6968 - accuracy: 0.9416 - val_loss: 0.7069 - val_accuracy: 0.9393
# Epoch 449/500
#
# Epoch 00449: val_accuracy did not improve from 0.97880
#
# Epoch 00449: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6979 - accuracy: 0.9398 - val_loss: 0.7022 - val_accuracy: 0.9407
# Epoch 450/500
#
# Epoch 00450: val_accuracy did not improve from 0.97880
#
# Epoch 00450: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6961 - accuracy: 0.9411 - val_loss: 0.7078 - val_accuracy: 0.9397
# Epoch 451/500
#
# Epoch 00451: val_accuracy did not improve from 0.97880
#
# Epoch 00451: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7018 - accuracy: 0.9398 - val_loss: 0.7048 - val_accuracy: 0.9403
# Epoch 452/500
#
# Epoch 00452: val_accuracy did not improve from 0.97880
#
# Epoch 00452: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7057 - accuracy: 0.9373 - val_loss: 0.7040 - val_accuracy: 0.9406
# Epoch 453/500
#
# Epoch 00453: val_accuracy did not improve from 0.97880
#
# Epoch 00453: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6979 - accuracy: 0.9407 - val_loss: 0.7068 - val_accuracy: 0.9396
# Epoch 454/500
#
# Epoch 00454: val_accuracy did not improve from 0.97880
#
# Epoch 00454: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7011 - accuracy: 0.9393 - val_loss: 0.7049 - val_accuracy: 0.9402
# Epoch 455/500
#
# Epoch 00455: val_accuracy did not improve from 0.97880
#
# Epoch 00455: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6975 - accuracy: 0.9410 - val_loss: 0.7059 - val_accuracy: 0.9398
# Epoch 456/500
#
# Epoch 00456: val_accuracy did not improve from 0.97880
#
# Epoch 00456: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6984 - accuracy: 0.9408 - val_loss: 0.7078 - val_accuracy: 0.9394
# Epoch 457/500
#
# Epoch 00457: val_accuracy did not improve from 0.97880
#
# Epoch 00457: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7009 - accuracy: 0.9395 - val_loss: 0.7085 - val_accuracy: 0.9385
# Epoch 458/500
#
# Epoch 00458: val_accuracy did not improve from 0.97880
#
# Epoch 00458: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7027 - accuracy: 0.9382 - val_loss: 0.7057 - val_accuracy: 0.9397
# Epoch 459/500
#
# Epoch 00459: val_accuracy did not improve from 0.97880
#
# Epoch 00459: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6986 - accuracy: 0.9402 - val_loss: 0.7046 - val_accuracy: 0.9404
# Epoch 460/500
#
# Epoch 00460: val_accuracy did not improve from 0.97880
#
# Epoch 00460: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6958 - accuracy: 0.9405 - val_loss: 0.7075 - val_accuracy: 0.9391
# Epoch 461/500
#
# Epoch 00461: val_accuracy did not improve from 0.97880
#
# Epoch 00461: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7020 - accuracy: 0.9395 - val_loss: 0.7072 - val_accuracy: 0.9397
# Epoch 462/500
#
# Epoch 00462: val_accuracy did not improve from 0.97880
#
# Epoch 00462: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6942 - accuracy: 0.9405 - val_loss: 0.7086 - val_accuracy: 0.9394
# Epoch 463/500
#
# Epoch 00463: val_accuracy did not improve from 0.97880
#
# Epoch 00463: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7005 - accuracy: 0.9399 - val_loss: 0.7056 - val_accuracy: 0.9399
# Epoch 464/500
#
# Epoch 00464: val_accuracy did not improve from 0.97880
#
# Epoch 00464: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7007 - accuracy: 0.9396 - val_loss: 0.7097 - val_accuracy: 0.9390
# Epoch 465/500
#
# Epoch 00465: val_accuracy did not improve from 0.97880
#
# Epoch 00465: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6988 - accuracy: 0.9404 - val_loss: 0.7045 - val_accuracy: 0.9401
# Epoch 466/500
#
# Epoch 00466: val_accuracy did not improve from 0.97880
#
# Epoch 00466: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6979 - accuracy: 0.9397 - val_loss: 0.7062 - val_accuracy: 0.9405
# Epoch 467/500
#
# Epoch 00467: val_accuracy did not improve from 0.97880
#
# Epoch 00467: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7025 - accuracy: 0.9396 - val_loss: 0.7048 - val_accuracy: 0.9404
# Epoch 468/500
#
# Epoch 00468: val_accuracy did not improve from 0.97880
#
# Epoch 00468: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6987 - accuracy: 0.9398 - val_loss: 0.7075 - val_accuracy: 0.9390
# Epoch 469/500
#
# Epoch 00469: val_accuracy did not improve from 0.97880
#
# Epoch 00469: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7006 - accuracy: 0.9396 - val_loss: 0.7052 - val_accuracy: 0.9403
# Epoch 470/500
#
# Epoch 00470: val_accuracy did not improve from 0.97880
#
# Epoch 00470: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6958 - accuracy: 0.9406 - val_loss: 0.7079 - val_accuracy: 0.9393
# Epoch 471/500
#
# Epoch 00471: val_accuracy did not improve from 0.97880
#
# Epoch 00471: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6975 - accuracy: 0.9403 - val_loss: 0.7082 - val_accuracy: 0.9394
# Epoch 472/500
#
# Epoch 00472: val_accuracy did not improve from 0.97880
#
# Epoch 00472: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6932 - accuracy: 0.9405 - val_loss: 0.7051 - val_accuracy: 0.9401
# Epoch 473/500
#
# Epoch 00473: val_accuracy did not improve from 0.97880
#
# Epoch 00473: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6997 - accuracy: 0.9398 - val_loss: 0.7027 - val_accuracy: 0.9408
# Epoch 474/500
#
# Epoch 00474: val_accuracy did not improve from 0.97880
#
# Epoch 00474: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7030 - accuracy: 0.9393 - val_loss: 0.7073 - val_accuracy: 0.9394
# Epoch 475/500
#
# Epoch 00475: val_accuracy did not improve from 0.97880
#
# Epoch 00475: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6989 - accuracy: 0.9395 - val_loss: 0.7057 - val_accuracy: 0.9400
# Epoch 476/500
#
# Epoch 00476: val_accuracy did not improve from 0.97880
#
# Epoch 00476: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7006 - accuracy: 0.9403 - val_loss: 0.7102 - val_accuracy: 0.9386
# Epoch 477/500
#
# Epoch 00477: val_accuracy did not improve from 0.97880
#
# Epoch 00477: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7003 - accuracy: 0.9392 - val_loss: 0.7050 - val_accuracy: 0.9399
# Epoch 478/500
#
# Epoch 00478: val_accuracy did not improve from 0.97880
#
# Epoch 00478: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7015 - accuracy: 0.9387 - val_loss: 0.7064 - val_accuracy: 0.9401
# Epoch 479/500
#
# Epoch 00479: val_accuracy did not improve from 0.97880
#
# Epoch 00479: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7010 - accuracy: 0.9403 - val_loss: 0.7036 - val_accuracy: 0.9399
# Epoch 480/500
#
# Epoch 00480: val_accuracy did not improve from 0.97880
#
# Epoch 00480: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7015 - accuracy: 0.9399 - val_loss: 0.7062 - val_accuracy: 0.9390
# Epoch 481/500
#
# Epoch 00481: val_accuracy did not improve from 0.97880
#
# Epoch 00481: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6971 - accuracy: 0.9420 - val_loss: 0.7035 - val_accuracy: 0.9409
# Epoch 482/500
#
# Epoch 00482: val_accuracy did not improve from 0.97880
#
# Epoch 00482: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7010 - accuracy: 0.9400 - val_loss: 0.7038 - val_accuracy: 0.9404
# Epoch 483/500
#
# Epoch 00483: val_accuracy did not improve from 0.97880
#
# Epoch 00483: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6980 - accuracy: 0.9400 - val_loss: 0.7071 - val_accuracy: 0.9402
# Epoch 484/500
#
# Epoch 00484: val_accuracy did not improve from 0.97880
#
# Epoch 00484: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7055 - accuracy: 0.9375 - val_loss: 0.7073 - val_accuracy: 0.9402
# Epoch 485/500
#
# Epoch 00485: val_accuracy did not improve from 0.97880
#
# Epoch 00485: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6970 - accuracy: 0.9390 - val_loss: 0.7029 - val_accuracy: 0.9407
# Epoch 486/500
#
# Epoch 00486: val_accuracy did not improve from 0.97880
#
# Epoch 00486: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6988 - accuracy: 0.9403 - val_loss: 0.7072 - val_accuracy: 0.9397
# Epoch 487/500
#
# Epoch 00487: val_accuracy did not improve from 0.97880
#
# Epoch 00487: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6978 - accuracy: 0.9410 - val_loss: 0.7079 - val_accuracy: 0.9393
# Epoch 488/500
#
# Epoch 00488: val_accuracy did not improve from 0.97880
#
# Epoch 00488: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6983 - accuracy: 0.9399 - val_loss: 0.7077 - val_accuracy: 0.9390
# Epoch 489/500
#
# Epoch 00489: val_accuracy did not improve from 0.97880
#
# Epoch 00489: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7012 - accuracy: 0.9391 - val_loss: 0.7072 - val_accuracy: 0.9397
# Epoch 490/500
#
# Epoch 00490: val_accuracy did not improve from 0.97880
#
# Epoch 00490: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6980 - accuracy: 0.9396 - val_loss: 0.7063 - val_accuracy: 0.9389
# Epoch 491/500
#
# Epoch 00491: val_accuracy did not improve from 0.97880
#
# Epoch 00491: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6970 - accuracy: 0.9417 - val_loss: 0.7057 - val_accuracy: 0.9402
# Epoch 492/500
#
# Epoch 00492: val_accuracy did not improve from 0.97880
#
# Epoch 00492: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7020 - accuracy: 0.9387 - val_loss: 0.7046 - val_accuracy: 0.9402
# Epoch 493/500
#
# Epoch 00493: val_accuracy did not improve from 0.97880
#
# Epoch 00493: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6996 - accuracy: 0.9409 - val_loss: 0.7042 - val_accuracy: 0.9405
# Epoch 494/500
#
# Epoch 00494: val_accuracy did not improve from 0.97880
#
# Epoch 00494: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6986 - accuracy: 0.9407 - val_loss: 0.7026 - val_accuracy: 0.9409
# Epoch 495/500
#
# Epoch 00495: val_accuracy did not improve from 0.97880
#
# Epoch 00495: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6992 - accuracy: 0.9392 - val_loss: 0.7041 - val_accuracy: 0.9410
# Epoch 496/500
#
# Epoch 00496: val_accuracy did not improve from 0.97880
#
# Epoch 00496: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6999 - accuracy: 0.9404 - val_loss: 0.7091 - val_accuracy: 0.9398
# Epoch 497/500
#
# Epoch 00497: val_accuracy did not improve from 0.97880
#
# Epoch 00497: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.7003 - accuracy: 0.9397 - val_loss: 0.7052 - val_accuracy: 0.9395
# Epoch 498/500
#
# Epoch 00498: val_accuracy did not improve from 0.97880
#
# Epoch 00498: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6981 - accuracy: 0.9408 - val_loss: 0.7043 - val_accuracy: 0.9405
# Epoch 499/500
#
# Epoch 00499: val_accuracy did not improve from 0.97880
#
# Epoch 00499: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6984 - accuracy: 0.9401 - val_loss: 0.7059 - val_accuracy: 0.9399
# Epoch 500/500
#
# Epoch 00500: val_accuracy did not improve from 0.97880
#
# Epoch 00500: accuracy did not improve from 0.94227
# 390/390 - 21s - loss: 0.6981 - accuracy: 0.9401 - val_loss: 0.7076 - val_accuracy: 0.9398
# Time taken: 7352.923053741455 seconds

# %%
import tensorflow
